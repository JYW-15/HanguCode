# %%
import pandas as pd
import numpy as np 
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import xgboost as xgb
from skopt.space import Real, Categorical, Integer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from skopt import BayesSearchCV
from sklearn.utils import resample

# %% [markdown]
# ## Environment

# %%
pip list
# Out:
# Package                            Version             Editable project location
# ---------------------------------- ------------------- -------------------------
# absl-py                            1.0.0
# aclpub-check                       0.1                 /Users/zhousiyi/ACLPUB
# adjustText                         0.7.3
# aiohttp                            3.8.4
# aiosignal                          1.3.1
# alabaster                          0.7.12
# alembic                            1.7.7
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              4.2.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.4
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# arrow                              1.3.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# asttokens                          2.4.1
# astunparse                         1.6.3
# async-generator                    1.10
# async-lru                          2.0.4
# async-timeout                      4.0.2
# atomicwrites                       1.4.0
# attrs                              23.2.0
# autopep8                           1.5.6
# Babel                              2.14.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.12.3
# bidict                             0.22.0
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             6.1.0
# blis                               0.7.7
# bokeh                              2.3.2
# Boruta                             0.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         5.0.0
# catalogue                          1.0.0
# certifi                            2024.2.2
# cffi                               1.16.0
# chardet                            4.0.0
# charset-normalizer                 3.3.2
# chinese-calendar                   1.7.2
# Ciw                                3.1.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# colorlover                         0.3.0
# colour                             0.1.5
# comm                               0.2.1
# conda                              4.12.0
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             2.2.0
# conda_package_streaming            0.9.0
# conda-repo-cli                     1.0.4
# conda-token                        0.4.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cpca                               0.5.5
# cryptography                       38.0.1
# cssselect                          1.1.0
# cufflinks                          0.17.3
# curio                              1.6
# cycler                             0.10.0
# cymem                              2.0.6
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# data                               0.4
# databricks-cli                     0.16.6
# debugpy                            1.8.1
# decorator                          5.1.1
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docker                             5.0.3
# docrepr                            0.2.0
# docutils                           0.20.1
# docx                               0.2.4
# dtreeviz                           1.3.7
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# exceptiongroup                     1.2.0
# executing                          2.0.1
# fastcache                          1.1.0
# fastjsonschema                     2.19.1
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# flatbuffers                        2.0
# fqdn                               1.5.1
# frozenlist                         1.3.3
# fsspec                             0.9.0
# funcsigs                           1.0.2
# funcy                              1.17
# future                             0.18.2
# gast                               0.5.3
# gensim                             3.8.3
# gevent                             21.1.2
# gitdb                              4.0.9
# GitPython                          3.1.27
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        2.6.4
# google-auth-oauthlib               0.4.6
# google-pasta                       0.2.0
# graphviz                           0.20.1
# greenlet                           1.0.0
# grpcio                             1.44.0
# gunicorn                           20.1.0
# gurobipy                           9.5.1
# gym                                0.26.2
# gym-notices                        0.0.8
# h11                                0.13.0
# h5py                               3.7.0
# hdbscan                            0.8.28
# HeapDict                           1.0.1
# html5lib                           1.1
# htmlmin                            0.1.12
# huggingface-hub                    0.5.1
# idna                               3.6
# ImageHash                          4.2.1
# imageio                            2.9.0
# imageio-ffmpeg                     0.4.8
# imagesize                          1.4.1
# imbalance-xgboost                  0.8.1
# imbalanced-ensemble                0.2.0
# imbalanced-learn                   0.10.1
# imblearn                           0.0
# importlib-metadata                 7.0.1
# importlib-resources                6.1.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.29.2
# ipyparallel                        8.6.1
# ipython                            8.12.3
# ipython-genutils                   0.2.0
# ipywidgets                         8.1.2
# isoduration                        20.11.0
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.19.1
# jieba                              0.42.1
# Jinja2                             3.1.3
# jiojio                             1.2.3
# jionlp                             1.4.21
# joblib                             1.2.0
# json5                              0.9.14
# jsonpointer                        2.4
# jsonschema                         4.21.1
# jsonschema-specifications          2023.12.1
# jupyter                            1.0.0
# jupyter_client                     7.4.9
# jupyter-console                    6.6.3
# jupyter_core                       5.7.1
# jupyter-events                     0.9.0
# jupyter-lsp                        2.2.2
# jupyter-packaging                  0.7.12
# jupyter_server                     2.12.5
# jupyter_server_terminals           0.5.2
# jupyterlab                         4.0.12
# jupyterlab_pygments                0.3.0
# jupyterlab_server                  2.25.2
# jupyterlab_widgets                 3.0.10
# jupyterthemes                      0.20.0
# keras                              2.8.0
# Keras-Preprocessing                1.1.2
# keyring                            22.3.0
# kiwisolver                         1.3.1
# kmodes                             0.12.1
# latex                              0.7.0
# lazy-object-proxy                  1.6.0
# lesscpy                            0.15.0
# libarchive-c                       2.9
# libclang                           13.0.0
# lightgbm                           3.1.1
# llvmlite                           0.36.0
# locket                             0.2.1
# lpsolve55                          5.5.0.9
# lxml                               4.6.3
# Mako                               1.2.0
# Markdown                           3.3.6
# MarkupSafe                         2.1.5
# matplotlib                         3.3.4
# matplotlib-inline                  0.1.6
# mccabe                             0.6.1
# missingno                          0.5.0
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mlflow                             1.25.1
# mlxtend                            0.19.0
# mock                               4.0.3
# more-itertools                     8.7.0
# moviepy                            1.0.3
# mpmath                             1.2.1
# msgpack                            1.0.2
# multidict                          6.0.4
# multimethod                        1.4
# multipledispatch                   0.6.0
# murmurhash                         1.0.6
# mypy-extensions                    0.4.3
# navigator-updater                  0.4.0
# nbclassic                          1.0.0
# nbclient                           0.5.13
# nbconvert                          6.4.4
# nbformat                           5.9.2
# nest-asyncio                       1.6.0
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           7.0.8
# notebook_shim                      0.2.3
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.22.3
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# openai                             0.27.1
# openpyxl                           3.0.7
# opt-einsum                         3.3.0
# outcome                            1.1.0
# overrides                          7.7.0
# packaging                          23.2
# pandas                             1.4.4
# pandas-profiling                   3.0.0
# pandocfilters                      1.5.1
# parso                              0.8.3
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pdfminer.six                       20220524
# pdfplumber                         0.7.5
# pep8                               1.7.1
# pexpect                            4.9.0
# phik                               0.12.0
# pickleshare                        0.7.5
# Pillow                             9.2.0
# pillow-heif                        0.11.0
# pip                                24.0
# pkginfo                            1.7.0
# pkgutil_resolve_name               1.3.10
# plac                               1.1.3
# platformdirs                       4.2.0
# plotly                             5.7.0
# pluggy                             0.13.1
# ply                                3.11
# preshed                            3.0.6
# prettytable                        3.7.0
# proglog                            0.1.10
# prometheus-client                  0.19.0
# prometheus-flask-exporter          0.20.1
# prompt-toolkit                     3.0.43
# protobuf                           3.20.0
# psutil                             5.9.8
# ptyprocess                         0.7.0
# pure-eval                          0.2.2
# py                                 1.10.0
# pyahocorasick                      2.0.0
# pyaml                              23.5.9
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# PyAstronomy                        0.17.1
# pycaret                            2.3.10
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.21
# pycurl                             7.43.0.6
# pydantic                           1.8.2
# pydocstyle                         6.0.0
# pyecharts                          2.0.3
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.17.2
# PyJWT                              2.3.0
# pyLDAvis                           3.2.2
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# pynndescent                        0.5.6
# pyod                               1.0.0
# pyodbc                             5.1.0
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pypdf                              3.8.1
# pypinyin                           0.46.0
# pyquery                            1.4.3
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# pytest-asyncio                     0.20.3
# python-dateutil                    2.8.2
# python-docx                        0.8.11
# python-json-logger                 2.0.7
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2024.1
# PyWavelets                         1.1.1
# PyYAML                             6.0.1
# pyzmq                              24.0.1
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.5.1
# QtPy                               2.4.1
# quantities                         0.13.0
# querystring-parser                 1.2.4
# referencing                        0.33.0
# regex                              2021.4.4
# requests                           2.31.0
# requests-oauthlib                  1.3.1
# rfc3339-validator                  0.1.4
# rfc3986-validator                  0.1.1
# rope                               0.18.0
# rpds-py                            0.17.1
# rsa                                4.8
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# sacremoses                         0.0.53
# scikit-image                       0.18.1
# scikit-learn                       1.2.2
# scikit-optimize                    0.9.0
# scikit-plot                        0.3.7
# scipy                              1.10.1
# seaborn                            0.12.1
# selenium                           4.1.3
# Send2Trash                         1.8.2
# sentence-transformers              2.2.2
# sentencepiece                      0.1.96
# setuptools                         52.0.0.post20210125
# shutilwhich                        1.1.0
# simplegeneric                      0.8.1
# simplejson                         3.19.1
# simpy                              4.0.1
# singledispatch                     0.0.0
# six                                1.16.0
# smart-open                         5.2.1
# smmap                              5.0.0
# sniffio                            1.3.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.5
# spacy                              2.3.7
# Sphinx                             7.1.2
# sphinx-rtd-theme                   2.0.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.1
# sphinxcontrib-jquery               4.1
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# sqlparse                           0.4.2
# srsly                              1.0.5
# stack-data                         0.6.3
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tabulate                           0.8.9
# tangled-up-in-unicode              0.1.0
# tblib                              1.7.0
# tempdir                            0.7.1
# tenacity                           8.0.1
# tensorboard                        2.8.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorboardX                       2.5.1
# tensorflow                         2.8.0
# tensorflow-io-gcs-filesystem       0.24.0
# termcolor                          1.1.0
# terminado                          0.18.0
# testpath                           0.4.4
# textblob                           0.17.1
# textdistance                       4.2.1
# tf-estimator-nightly               2.8.0.dev2021122109
# thinc                              7.4.5
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2020.10.1
# tinycss2                           1.2.1
# tokenizers                         0.12.1
# toml                               0.10.2
# tomli                              2.0.1
# toolz                              0.11.1
# torch                              1.11.0
# torch-tb-profiler                  0.4.1
# torchvision                        0.12.0
# tornado                            6.4
# tqdm                               4.64.1
# traitlets                          5.14.1
# transformers                       4.18.0
# trio                               0.20.0
# trio-websocket                     0.9.2
# typed-ast                          1.4.2
# types-python-dateutil              2.8.19.20240106
# typing_extensions                  4.9.0
# ujson                              4.0.2
# umap-learn                         0.5.3
# unicodecsv                         0.14.1
# uri-template                       1.3.0
# urllib3                            2.2.0
# visions                            0.7.1
# Wand                               0.6.10
# wasabi                             0.9.1
# watchdog                           1.0.2
# wcwidth                            0.2.13
# webcolors                          1.13
# webencodings                       0.5.1
# websocket-client                   1.7.0
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 4.0.10
# wordcloud                          1.8.1
# wrapt                              1.12.1
# wsproto                            1.1.0
# wurlitzer                          2.1.0
# xgboost                            1.6.2
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.13.0
# yapf                               0.31.0
# yarl                               1.8.2
# yellowbrick                        1.3.post1
# zict                               2.0.0
# zipfile36                          0.1.3
# zipp                               3.17.0
# zope.event                         4.5.0
# zope.interface                     5.3.0
# zstandard                          0.19.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Feature engineering

# %%
df1 = pd.read_csv('Data.csv')

# %%
df1['Address'] = df1['Address'].apply(lambda x : 'NA' if pd.isnull(x) else x)
df1['if_return'] = df1['Visit.No'].apply(lambda x: True if x>1 else False)

# %%
cal_session = min(df1[df1['Session']==2].index)
df1['duration_history2'] = pd.NA
for i in range(cal_session,len(df1)):#The patient's past visits were calculated from the second session
    session = df1.loc[i,'Session']
    if df1.loc[i,'if_return']:#If s/he is a return patient
        id = df1.loc[i,'ID']
        df_temp = df1[(df1['ID']==id)&(df1['Session']<session)]['ServTime'].values#Excluding the data of the same session, only the data of previous sessions can be used for calculation
        if len(df_temp)!=0:
            df1.loc[i,'duration_history2'] = np.mean(df_temp)
        else:
            df1.loc[i,'duration_history2'] = pd.NA#Leave the missing pieces intact and fill in the next 15 minutes
    else:#If s/he is a new patient
        df_temp = df1[(df1['if_return']==False)&(df1['Session']<session)]['ServTime'].values
        df1.loc[i,'duration_history2'] = np.mean(df_temp)

# %%
df1['duration_history2'] = df1['duration_history2'].fillna(900)#Take 15 minutes to fill in the missing values

# %%
train_start = min(df1[df1['Session']==2].index)
train_end = max(df1[df1['Session']==194].index)
session1_len = len(df1[df1['Session']==1])
def data_process(df,feature,duration_history,y):
    data = df[feature]
    data = pd.get_dummies(data,columns = ['Gender','Address'], drop_first=True)#one-hot
    data_x = data.drop([y],axis = 1)
    data_y = data[y]
    x_train = data_x.loc[:train_end,].copy()
    x_test = data_x.loc[train_end+1:,].copy()
    y_train = data_y.loc[:train_end,].copy()
    y_test = data_y.loc[train_end+1:,].copy()
    for i in [duration_history,'Visit.No']:#normalization
        x1 = np.array(x_train.loc[:,i]).reshape(-1,1)
        scaler = StandardScaler()
        scaler.fit(x1)
        x_train[i+'_scaled'] = scaler.transform(x1).reshape(1,-1)[0]
        x2 = np.array(x_test.loc[:,i]).reshape(-1,1)
        x_test[i+'_scaled'] = scaler.transform(x2).reshape(1,-1)[0]
    x_train = x_train.drop(['Visit.No',duration_history],axis = 1)
    x_test = x_test.drop(['Visit.No',duration_history],axis = 1)
    return x_train, x_test, y_train, y_test

# %%
input_feature = ['Visit.No','M.Cancer','S.Cancer','Gender','ServTime','if_return','duration_history2','Address']
x_train, x_test, y_train, y_test = data_process(df1,input_feature,'duration_history2','ServTime')

# %% [markdown]
# ## Training model

# %%
def MAPE(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def eval_model(xtrain_pred,ytrain,predictions,groundtrue):
    print('--------------train----------------')
    print('RMSE',np.sqrt(mean_squared_error(ytrain,xtrain_pred)))
    print('MAPE',MAPE(ytrain,xtrain_pred))
    print('MAE',mean_absolute_error(ytrain,xtrain_pred))
    print('R^2 test: %.3f' % (r2_score(ytrain,xtrain_pred)))
    print('--------------test----------------')
    print('RMSE',np.sqrt(mean_squared_error(groundtrue,predictions)))
    print('MAPE',MAPE(groundtrue,predictions))
    print('MAE',mean_absolute_error(groundtrue,predictions))
    print('R^2 test: %.3f' % (r2_score(groundtrue,predictions)))
    print('--------------eval by group--------------')
    eval = pd.DataFrame({'pred':predictions,'true':groundtrue})
    eval['class'] = eval['pred'].apply(lambda x: 'short' if x<=630.5 else ('long' if x>975.5 else 'median'))
    eval['class2'] = eval['pred'].apply(lambda x: 'short' if x<=811.5 else 'long')
    df = eval.groupby('class').agg({'true':['count',lambda x: x.count() / len(eval),'mean','median','var']})
    print(df)
    df1 = eval.groupby('class2').agg({'true':['count',lambda x: x.count() / len(eval),'mean','median','var']})
    print(df1)

# %%
def model_fit(model,params,train_x,train_y,test_x,seed):
    bayes_search = BayesSearchCV(model, params, scoring='neg_mean_squared_error',verbose=2,cv=10,random_state=seed)
    bayes_search.fit(train_x,train_y)
    bestparam = bayes_search.best_params_
    print('bestparam:',bestparam)
    bestmodel = bayes_search.best_estimator_
    pred_test = bestmodel.predict(test_x)
    pred_train = bestmodel.predict(train_x)
    return bayes_search,bestmodel,bestparam,pred_test,pred_train
param_space_xgb = {
    'colsample_bytree': Real(0.4,0.9),
    'colsample_bylevel':Real(0.4,0.9),
    'learning_rate': Categorical([0.1]),
    'lambda':Real(0,200),
    'alpha':Real(0,200),
    'gamma':Real(0,200),
    'n_estimators': Categorical([100,300,500]),
    'max_depth': Integer(2,6),
    'min_child_weight':Integer(1,10)
}

# %% [markdown]
# ### xgb

# %%
xgb_reg = xgb.XGBRegressor(random_state=42)
xgb_bayse,xgb_model,xgb_model_param,xgb_predictions,xgb_train = model_fit(xgb_reg,param_space_xgb,x_train, y_train, x_test, seed = 55)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.4s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.3s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.3s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.3s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=158.807024300404, colsample_bylevel=0.7800647945904826, colsample_bytree=0.8501681628173743, gamma=15.910167904632159, lambda=54.557374029227525, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.4s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.3s
# [CV] END alpha=87.07587419623006, colsample_bylevel=0.444772319002761, colsample_bytree=0.7659278050202216, gamma=83.48958002235337, lambda=162.64790714055562, learning_rate=0.1, max_depth=5, min_child_weight=8, n_estimators=500; total time=   0.3s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.2s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.3s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.3s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.2s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.3s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.3s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.3s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.2s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.2s
# [CV] END alpha=94.21110952639975, colsample_bylevel=0.7842237202106458, colsample_bytree=0.5653098180573002, gamma=194.4027242536943, lambda=48.58624361541089, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=300; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.2s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.2s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.4s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=32.04469069560395, colsample_bylevel=0.840641421534533, colsample_bytree=0.7945408610395379, gamma=38.047288145785586, lambda=49.405183506691955, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=300; total time=   0.3s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.4s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.3s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.2s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.3s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.3s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.3s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.2s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.3s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.2s
# [CV] END alpha=10.889248361796081, colsample_bylevel=0.5328214267887861, colsample_bytree=0.6684409132993344, gamma=169.91362338886265, lambda=165.76576444872796, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300; total time=   0.3s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=6.560414635680402, colsample_bylevel=0.5484839978017045, colsample_bytree=0.5376653104546577, gamma=194.59298830432297, lambda=105.20901978593858, learning_rate=0.1, max_depth=3, min_child_weight=8, n_estimators=300; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=51.6009805754902, colsample_bylevel=0.4408660339717803, colsample_bytree=0.6040742532506413, gamma=148.74267327700682, lambda=141.639322954778, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# [CV] END alpha=169.38167993418543, colsample_bylevel=0.6372001927579827, colsample_bytree=0.7923683170513254, gamma=61.582149456979984, lambda=128.67786204524458, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.3s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.3s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# [CV] END alpha=19.909424460785058, colsample_bylevel=0.5059255105710991, colsample_bytree=0.8450920397833828, gamma=10.642085170281094, lambda=54.47298715730907, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=500; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.4s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.4s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.4s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.3s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.4s
# [CV] END alpha=14.678892833121985, colsample_bylevel=0.750676304570058, colsample_bytree=0.8109145268781603, gamma=52.382338019302935, lambda=69.36923308576722, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=300; total time=   0.3s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=131.69182920446465, colsample_bylevel=0.5363990866167235, colsample_bytree=0.4994388854452904, gamma=192.98676896652697, lambda=172.27956233727787, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=49.819432392564146, colsample_bylevel=0.4422522990650735, colsample_bytree=0.600228466491022, gamma=150.45223797678645, lambda=139.34236132604042, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=50.074628490564024, colsample_bylevel=0.43869539793850776, colsample_bytree=0.6206807868514667, gamma=140.98460006276866, lambda=145.87838501190694, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=52.034660724858206, colsample_bylevel=0.44743108584421043, colsample_bytree=0.5661366522581224, gamma=174.62568370162023, lambda=126.06711651084457, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=41.52694245005858, colsample_bylevel=0.4314652119397688, colsample_bytree=0.6769359682407878, gamma=86.70551223038926, lambda=175.61034802081136, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.278243365153386, colsample_bylevel=0.43356921817621297, colsample_bytree=0.6224133609804408, gamma=137.60217656203605, lambda=140.00680788974034, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=74.76897198550618, colsample_bylevel=0.4, colsample_bytree=0.6752614718823087, gamma=65.4940973221934, lambda=136.93932704816066, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.2s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.2s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=35.1782256733524, colsample_bylevel=0.4216302090938979, colsample_bytree=0.8284677137540398, gamma=140.27148735466372, lambda=118.61618169707975, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=43.08262731823851, colsample_bylevel=0.4254242209009637, colsample_bytree=0.7039736359605022, gamma=143.87050773314724, lambda=119.17961131985821, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# ...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6217173894591848, gamma=199.34139911714567, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=300; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.3s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.4s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.2s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.2s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.2s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.2s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.2s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.2s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.3s
# [CV] END alpha=38.469987648497586, colsample_bylevel=0.49643636386748313, colsample_bytree=0.8917234047863046, gamma=24.528610223069926, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=500; total time=   0.3s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.3s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.7974849783286965, gamma=9.156873743469843, lambda=42.038646507447396, learning_rate=0.1, max_depth=2, min_child_weight=3, n_estimators=500; total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6247004295003679, gamma=111.23376516265098, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=6, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.2s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# [CV] END alpha=34.45701447499505, colsample_bylevel=0.4, colsample_bytree=0.6320089323506048, gamma=9.731190818709534, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=8, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.4, colsample_bytree=0.6223632834071882, gamma=19.14935936899361, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.2s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# [CV] END alpha=0.0, colsample_bylevel=0.6803599740819182, colsample_bytree=0.6126427291067349, gamma=16.807304667550483, lambda=0.0, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=300; total time=   0.1s
# bestparam: OrderedDict([('alpha', 0.0), ('colsample_bylevel', 0.4), ('colsample_bytree', 0.6247342336117867), ('gamma', 200.0), ('lambda', 0.0), ('learning_rate', 0.1), ('max_depth', 2), ('min_child_weight', 5), ('n_estimators', 300)])

# %%
eval_model(xgb_train,y_train,xgb_predictions,y_test)
# Out:
# --------------train----------------
# RMSE 326.42679730513106
# MAPE 34.89118219779518
# MAE 240.93698417109587
# R^2 test: 0.187
# --------------test----------------
# RMSE 366.6359920470354
# MAPE 40.41809229207963
# MAE 268.78459992503605
# R^2 test: 0.085
# --------------eval by group--------------
#         true
#        count <lambda_0>         mean  median            var
# class
# long     193   0.058168  1050.176166  1003.0  220534.541721
# median  2698   0.813140   810.690141   739.0  142286.123455
# short    427   0.128692   609.524590   559.0   78939.353267
#         true
#        count <lambda_0>        mean median            var
# class2
# long    1665   0.501808  900.890691  820.0  179974.159919
# short   1653   0.498192  695.831821  633.0   92757.020125

# %%
test_data = np.hstack([x_test, np.array(y_test).reshape(-1,1)])

# Bootstrap 
n_bootstraps = 1000

# Save the model performance indicators obtained from each resampling
score_rmse = []
score_r_square = []
score_mape = []
score_mae = []

#  Bootstrap 
for i in range(n_bootstraps):
    # Take a number of samples from the test set with put backs to form a new dataset
    test_data_resampled = resample(test_data, replace=True, n_samples=len(test_data), random_state=i)
    x_test_resampled = test_data_resampled[:, :-1]
    y_test_resampled = test_data_resampled[:, -1]

    # Model Evaluation on Bootstrap Resampled Test Sets
    y_pred = xgb_model.predict(x_test_resampled)
    rmse = np.sqrt(mean_squared_error(y_test_resampled, y_pred))
    r2 = r2_score(y_test_resampled,y_pred)
    mape = MAPE(y_test_resampled,y_pred)
    mae = mean_absolute_error(y_test_resampled,y_pred)
    score_rmse.append(rmse)
    score_r_square.append(r2)
    score_mape.append(mape)
    score_mae.append(mae)

# Calculate confidence intervals and means for model performance metrics after Bootstrap resampling
confidence_interval1 = np.percentile(score_rmse, [2.5, 97.5])
mean_score1 = np.mean(score_rmse)
confidence_interval2 = np.percentile(score_r_square, [2.5, 97.5])
mean_score2 = np.mean(score_r_square)
confidence_interval3 = np.percentile(score_mape, [2.5, 97.5])
mean_score3 = np.mean(score_mape)
confidence_interval4 = np.percentile(score_mae,[2.5, 97.5])
mean_score4 = np.mean(score_mae)
print('rmse')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score1))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval1[0], confidence_interval1[1]))
print('r2')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score2))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval2[0], confidence_interval2[1]))
print('mape')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score3))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval3[0], confidence_interval3[1]))
print('mae')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score4))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval4[0], confidence_interval4[1]))
# Out:
# rmse
# Mean performance metrics after Bootstrap resampling: 366.150
# Confidence interval of performance metrics after Bootstrap resampling: [349.105, 382.330]
# r2
# Mean performance metrics after Bootstrap resampling: 0.085
# Confidence interval of performance metrics after Bootstrap resampling: [0.059, 0.111]
# mape
# Mean performance metrics after Bootstrap resampling: 40.441
# Confidence interval of performance metrics after Bootstrap resampling: [38.949, 41.972]
# mae
# Mean performance metrics after Bootstrap resampling: 268.646
# Confidence interval of performance metrics after Bootstrap resampling: [260.193, 276.885]

# %% [markdown]
# ### svr

# %%
param_space_svr = {
    'C': Real(0.01,100),
    'gamma':Real(0.01,100),
    'kernel': Categorical(['rbf'])
}
svr = SVR()
svr_bayse,svr_model,svr_model_param,svr_predictions,svr_train = model_fit(svr,param_space_svr,x_train, y_train, x_test, seed = 55)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.5s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# [CV] END C=79.40557179898698, gamma=76.0153576222047, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# [CV] END C=43.54358330440522, gamma=8.963568354172137, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# [CV] END C=47.11084420772355, gamma=76.84705956772494, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# [CV] END C=16.030743113267192, gamma=88.12947147847592, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# [CV] END C=5.45407971847995, gamma=26.57162892922143, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# [CV] END C=3.2898792971084165, gamma=29.703829880384863, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# [CV] END C=25.807910238716325, gamma=8.182389473676624, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# [CV] END C=84.692370883096, gamma=47.445294547741355, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# [CV] END C=9.96371675916949, gamma=21.192983604008408, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# [CV] END C=7.3487124719193355, gamma=70.13824738792017, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......C=43.439409340425385, gamma=0.01, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# [CV] END C=43.94312170206837, gamma=14.335741204229956, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# [CV] END C=48.71695301377107, gamma=25.56399028628823, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........C=95.79940177536639, gamma=0.01, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# /Users/zhousiyi/opt/anaconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100.0, gamma=0.01, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# [CV] END C=78.39069152191642, gamma=12.319651313561161, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# [CV] END C=79.43870186285399, gamma=12.625018458985885, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.5s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# [CV] END C=80.41206349886858, gamma=12.731682579445888, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# [CV] END C=83.59633184981301, gamma=13.103470942579355, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# [CV] END C=87.17920771156975, gamma=13.361484790734824, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# [CV] END C=90.88743923044541, gamma=13.494457365696213, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# [CV] END C=94.53496907585593, gamma=13.529664862957643, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# [CV] END C=98.51235110455669, gamma=13.488107432911235, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=13.45687011011145, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=25.720141764011196, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=12.795508683496719, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=11.57699486291495, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=10.478560359777903, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=9.294045659296195, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=8.33954706821239, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=7.460545735648363, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# [CV] END ........C=100.0, gamma=6.66636083182888, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=6.004458959956923, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=5.441778214885622, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=4.927881225371081, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.4472507387145805, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=4.0290178690040115, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.6887984405205554, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.5s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# [CV] END ......C=100.0, gamma=3.3924605111115853, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.151271410460541, kernel=rbf; total time=   0.5s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.5s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# [CV] END ...................C=100.0, gamma=100.0, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.5s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=56.27601983482505, kernel=rbf; total time=   0.5s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.5s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# [CV] END .......C=100.0, gamma=3.006571537054538, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.5s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.5s
# [CV] END C=97.69329389279946, gamma=2.9748115021386057, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.5s
# [CV] END C=95.85647187036408, gamma=3.023762483040881, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.5s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.5s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# [CV] END C=95.51830238323173, gamma=3.0353775878637808, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.5s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# [CV] END C=95.50362618325023, gamma=3.0354272466234047, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# [CV] END C=95.46763530433655, gamma=3.0365450475206375, kernel=rbf; total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# [CV] END C=94.30705539544422, gamma=3.0927758177036204, kernel=rbf; total time=   0.4s
# bestparam: OrderedDict([('C', 95.85647187036408), ('gamma', 3.023762483040881), ('kernel', 'rbf')])

# %%
eval_model(svr_train,y_train,svr_predictions,y_test)
# Out:
# --------------train----------------
# RMSE 331.78024557872106
# MAPE 30.422580349163603
# MAE 228.0508738344116
# R^2 test: 0.160
# --------------test----------------
# RMSE 374.2866873417175
# MAPE 37.424124374385734
# MAE 266.97405350676826
# R^2 test: 0.047
# --------------eval by group--------------
#         true
#        count <lambda_0>         mean  median            var
# class
# long      73   0.022001  1219.027397  1278.0  207585.943683
# median  2557   0.770645   821.620258   750.0  147170.978979
# short    688   0.207354   669.071221   590.0  102873.702344
#         true
#        count <lambda_0>        mean median            var
# class2
# long    1086   0.327306  903.795580  829.5  174355.405179
# short   2232   0.672694  747.612455  676.5  125770.934905

# %%
# Save the model performance indicators obtained from each resampling
score_rmse = []
score_r_square = []
score_mape = []
score_mae = []

#  Bootstrap 
for i in range(n_bootstraps):
    # Take a number of samples from the test set with put backs to form a new dataset
    test_data_resampled = resample(test_data, replace=True, n_samples=len(test_data), random_state=i)
    x_test_resampled = pd.DataFrame(test_data_resampled[:, :-1],columns=x_train.columns)
    y_test_resampled = test_data_resampled[:, -1]

    # Model Evaluation on Bootstrap Resampled Test Sets
    y_pred = svr_model.predict(x_test_resampled)
    rmse = np.sqrt(mean_squared_error(y_test_resampled, y_pred))
    r2 = r2_score(y_test_resampled,y_pred)
    mape = MAPE(y_test_resampled,y_pred)
    mae = mean_absolute_error(y_test_resampled,y_pred)
    score_rmse.append(rmse)
    score_r_square.append(r2)
    score_mape.append(mape)
    score_mae.append(mae)

# Calculate confidence intervals and means for model performance metrics after Bootstrap resampling
confidence_interval1 = np.percentile(score_rmse, [2.5, 97.5])
mean_score1 = np.mean(score_rmse)
confidence_interval2 = np.percentile(score_r_square, [2.5, 97.5])
mean_score2 = np.mean(score_r_square)
confidence_interval3 = np.percentile(score_mape, [2.5, 97.5])
mean_score3 = np.mean(score_mape)
confidence_interval4 = np.percentile(score_mae,[2.5, 97.5])
mean_score4 = np.mean(score_mae)
print('rmse')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score1))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval1[0], confidence_interval1[1]))
print('r2')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score2))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval2[0], confidence_interval2[1]))
print('mape')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score3))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval3[0], confidence_interval3[1]))
print('mae')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score4))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval4[0], confidence_interval4[1]))
# Out:
# rmse
# Mean performance metrics after Bootstrap resampling: 373.665
# Confidence interval of performance metrics after Bootstrap resampling: [356.624, 390.968]
# r2
# Mean performance metrics after Bootstrap resampling: 0.047
# Confidence interval of performance metrics after Bootstrap resampling: [0.024, 0.071]
# mape
# Mean performance metrics after Bootstrap resampling: 37.436
# Confidence interval of performance metrics after Bootstrap resampling: [36.086, 38.794]
# mae
# Mean performance metrics after Bootstrap resampling: 266.763
# Confidence interval of performance metrics after Bootstrap resampling: [257.939, 275.425]

# %% [markdown]
# ### lr

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
print('coef',lr.coef_)
print('intercept',lr.intercept_)

lr_predictions = lr.predict(x_test)
lr_train = lr.predict(x_train)
eval_model(lr_train,y_train,lr_predictions,y_test)
# Out:
# coef [ 157.15177678  115.43417208 -187.4018734   -13.77195628   14.40759647
#    46.69267981  163.23042705   52.88481447   11.17336462]
# intercept 887.4299963720251
# --------------train----------------
# RMSE 340.8302635222
# MAPE 36.838510800963164
# MAE 252.81531198287507
# R^2 test: 0.114
# --------------test----------------
# RMSE 367.15745478915426
# MAPE 41.45027744171662
# MAE 272.9112891798674
# R^2 test: 0.083
# --------------eval by group--------------
#         true
#        count <lambda_0>         mean median            var
# class
# long     255   0.076854  1029.101961  963.0  200058.170665
# median  2874   0.866184   792.733820  720.0  138756.654846
# short    189   0.056962   579.126984  492.0   81793.324215
#         true
#        count <lambda_0>        mean median            var
# class2
# long    1743   0.525316  884.572002  803.0  176792.843119
# short   1575   0.474684  703.735873  641.0   96925.825999

# %%
# Save the model performance indicators obtained from each resampling
score_rmse = []
score_r_square = []
score_mape = []
score_mae = []

#  Bootstrap 
for i in range(n_bootstraps):
    # Take a number of samples from the test set with put backs to form a new dataset
    test_data_resampled = resample(test_data, replace=True, n_samples=len(test_data), random_state=i)
    x_test_resampled = pd.DataFrame(test_data_resampled[:, :-1],columns=x_train.columns)
    y_test_resampled = test_data_resampled[:, -1]

    # Model Evaluation on Bootstrap Resampled Test Sets
    y_pred = lr.predict(x_test_resampled)
    rmse = np.sqrt(mean_squared_error(y_test_resampled, y_pred))
    r2 = r2_score(y_test_resampled,y_pred)
    mape = MAPE(y_test_resampled,y_pred)
    mae = mean_absolute_error(y_test_resampled,y_pred)
    score_rmse.append(rmse)
    score_r_square.append(r2)
    score_mape.append(mape)
    score_mae.append(mae)

# Calculate confidence intervals and means for model performance metrics after Bootstrap resampling
confidence_interval1 = np.percentile(score_rmse, [2.5, 97.5])
mean_score1 = np.mean(score_rmse)
confidence_interval2 = np.percentile(score_r_square, [2.5, 97.5])
mean_score2 = np.mean(score_r_square)
confidence_interval3 = np.percentile(score_mape, [2.5, 97.5])
mean_score3 = np.mean(score_mape)
confidence_interval4 = np.percentile(score_mae,[2.5, 97.5])
mean_score4 = np.mean(score_mae)
print('rmse')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score1))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval1[0], confidence_interval1[1]))
print('r2')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score2))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval2[0], confidence_interval2[1]))
print('mape')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score3))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval3[0], confidence_interval3[1]))
print('mae')
print("Mean performance metrics after Bootstrap resampling: {:.3f}".format(mean_score4))
print("Confidence interval of performance metrics after Bootstrap resampling: [{:.3f}, {:.3f}]".format(confidence_interval4[0], confidence_interval4[1]))
# Out:
# rmse
# Mean performance metrics after Bootstrap resampling: 366.654
# Confidence interval of performance metrics after Bootstrap resampling: [351.120, 382.334]
# r2
# Mean performance metrics after Bootstrap resampling: 0.082
# Confidence interval of performance metrics after Bootstrap resampling: [0.062, 0.102]
# mape
# Mean performance metrics after Bootstrap resampling: 41.466
# Confidence interval of performance metrics after Bootstrap resampling: [39.979, 42.992]
# mae
# Mean performance metrics after Bootstrap resampling: 272.749
# Confidence interval of performance metrics after Bootstrap resampling: [264.342, 280.785]
